# %% [markdown]
# # Federated Image Classification with ResNet-18 Using Delta

# %%
# !pip install torch torchvision -q

# %% [markdown]
# ## Importing Required Libraries
#
# This section imports the libraries required for building the Federated Learning pipeline.
#
# The notebook mainly uses:
#
# - PyTorch for deep learning
# - Torchvision for datasets and transforms
# - NumPy for numerical operations
# - Matplotlib for plotting results
#
# These libraries together help in model training, client simulation, and evaluation.

# %%
import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import datasets, transforms
from torchvision.models import resnet18

from torch.utils.data import DataLoader, Subset

import numpy as np
import matplotlib.pyplot as plt
import time
import copy
import gc

# %% [markdown]
# ## Configuring the Training Device
#
# This cell checks whether CUDA is available.
#
# If a GPU is detected, training is performed on the GPU; otherwise, the CPU is used.
#
# Using a GPU significantly speeds up deep learning training, especially for convolutional neural networks like ResNet-18.

# %%
DEVICE = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

print("Using Device:", DEVICE)

if torch.cuda.is_available():

    print(
        "GPU:",
        torch.cuda.get_device_name(0)
    )
# Out:
# Using Device: cuda
# GPU: Tesla T4

# %% [markdown]
# ## Defining Federated Learning Hyperparameters
#
# This section defines the main training settings used throughout the experiment.
#
# Some important parameters include:
#
# - Number of clients
# - Clients selected per round
# - Number of communication rounds
# - Local epochs
# - Batch size
# - Learning rate
#
# These values directly affect convergence speed, communication cost, and overall model performance.

# %%
NUM_CLIENTS = 20

CLIENTS_PER_ROUND = 10

ROUNDS = 20

LOCAL_EPOCHS = 1

BATCH_SIZE = 16

LEARNING_RATE = 0.0003

ALPHA=0.5

# %% [markdown]
# ## Applying Image Transformations
#
# Before training, the images are preprocessed using augmentation and normalization techniques.
#
# The training data uses:
#
# - Random cropping
# - Horizontal flipping
# - Normalization
#
# These transformations help improve generalization and reduce overfitting.
#
# ---
#
# ## Normalization
#
# Pixel values are normalized using:   $x' = \frac{x - \mu}{\sigma}$
#
#
# where:
#
# - $\mu$ is the dataset mean
# - $\sigma$ is the standard deviation

# %%
transform_train = transforms.Compose([

    transforms.RandomCrop(32, padding=4),

    transforms.RandomHorizontalFlip(),

    transforms.ToTensor(),

    transforms.Normalize(
        (0.5, 0.5, 0.5),
        (0.5, 0.5, 0.5)
    )
])

transform_test = transforms.Compose([

    transforms.ToTensor(),

    transforms.Normalize(
        (0.5, 0.5, 0.5),
        (0.5, 0.5, 0.5)
    )
])

# %% [markdown]
# # Loading the CIFAR-100 Dataset
#
# ## What this code does
# This cell downloads and loads:
# - Training dataset
# - Testing dataset
#
# using the CIFAR-100 dataset from Torchvision.
#
# ## About CIFAR-100
# CIFAR-100 contains:
# - 60,000 color images
# - 100 different classes
# - 32×32 image size
#
# ## Dataset Split
# - 50,000 training images
# - 10,000 testing images
#
# ## Why this dataset is used
# CIFAR-100 is commonly used for:
# - Image classification research
# - Federated Learning experiments
# - Deep learning benchmarking
#
# Its large number of classes makes the learning task more challenging.

# %%
train_dataset = datasets.CIFAR100(
    root='./data',
    train=True,
    download=True,
    transform=transform_train
)

test_dataset = datasets.CIFAR100(
    root='./data',
    train=False,
    download=True,
    transform=transform_test
)

print("Training Samples:", len(train_dataset))

print("Testing Samples:", len(test_dataset))
# Out:
# Training Samples: 50000
# Testing Samples: 10000

# %% [markdown]
# ## Creating Non-IID Client Datasets
#
# In Federated Learning, client datasets are usually not identically distributed.
#
# This section creates a Non-IID partition of CIFAR-100 across multiple clients.
#
#
# ### IID vs Non-IID Distribution
#
# IID distribution assumes:  $P_k(x,y) = P(x,y)$
#
#
# Non-IID distribution means: $P_k(x,y) \neq P_j(x,y)$
#
# This means different clients may contain different class distributions.
#
# For example:
#
# - One client may mostly contain animal images
# - Another may mostly contain vehicle images
#
# This setup better reflects real-world decentralized data.

# %%
def dirichlet_split(
    dataset,
    num_clients,
    alpha=0.5
):

    labels = np.array(dataset.targets)

    num_classes = 100

    client_indices = [
        [] for _ in range(num_clients)
    ]

    for class_id in range(num_classes):

        class_indices = np.where(
            labels == class_id
        )[0]

        np.random.shuffle(class_indices)

        proportions = np.random.dirichlet(
            [alpha] * num_clients
        )

        proportions = (
            np.cumsum(proportions)
            * len(class_indices)
        ).astype(int)[:-1]

        split_indices = np.split(
            class_indices,
            proportions
        )

        for client_id in range(num_clients):

            client_indices[client_id].extend(
                split_indices[client_id]
            )

    return client_indices

# %% [markdown]
# # Generating Federated Clients
#
# ## What this code does
# This cell creates all client datasets using the previously defined Non-IID partitioning function.
#
# ## Output
# - 20 simulated clients are created
# - Each client contains a different subset of CIFAR-100 classes
#
# ## Why this is important
# Federated Learning requires:
# - Multiple decentralized clients
# - Independent local datasets
#
# This step simulates distributed user data.

# %%
client_indices = dirichlet_split(
    train_dataset,
    NUM_CLIENTS,
    ALPHA
)

client_loaders = []

for client_id in range(NUM_CLIENTS):

    subset = Subset(
        train_dataset,
        client_indices[client_id]
    )

    loader = DataLoader(
        subset,
        batch_size=BATCH_SIZE,
        shuffle=True
    )

    client_loaders.append(loader)

    print(
        f"Client {client_id} "
        f"has {len(subset)} samples"
    )
# Out:
# Client 0 has 2307 samples
# Client 1 has 3056 samples
# Client 2 has 2448 samples
# Client 3 has 2261 samples
# Client 4 has 2508 samples
# Client 5 has 2895 samples
# Client 6 has 2791 samples
# Client 7 has 2310 samples
# Client 8 has 2634 samples
# Client 9 has 2540 samples
# Client 10 has 2407 samples
# Client 11 has 2626 samples
# Client 12 has 2290 samples
# Client 13 has 2529 samples
# Client 14 has 2728 samples
# Client 15 has 2287 samples
# Client 16 has 2356 samples
# Client 17 has 2328 samples
# Client 18 has 1736 samples
# Client 19 has 2963 samples

# %% [markdown]
# # Initializing the Global ResNet-18 Model
#
# This section initializes the global model used for Federated Learning.
#
# The architecture used is ResNet-18, which introduces residual connections to improve deep network training.
#
# ---
#
# ## Residual Learning
#
# Instead of learning a direct mapping, ResNet learns: $H(x) = F(x) + x$
#
# where:
#
# - $F(x)$ is the residual mapping
# - $x$ is the shortcut connection
#
# These skip connections help reduce the vanishing gradient problem in deep neural networks.

# %%
global_model = resnet18(
    num_classes=100
).to(DEVICE)

print("Global Model Initialized")
# Out:
# Global Model Initialized

# %% [markdown]
# ## Local Client Training
#
# This function performs local optimization on a client's private dataset.
#
# Each client updates the model weights independently using gradient descent.
#
# ---
#
# ## Local Weight Update
#
# The parameter update rule is:
#
# $\theta_{t+1}
# =
# \theta_t
# -
# \eta \nabla \mathcal{L}(\theta_t)$
#
# where:
#
# - $\eta$ is the learning rate
# - $\mathcal{L}$ is the loss function
# - $\nabla \mathcal{L}$ is the gradient
#
# After local training, the client computes the weight difference relative to the received global model.

# %% [markdown]
# ## Computing Delta Weights
#
# Instead of sending the full model weights back to the server, each client sends only the weight updates.
#
# This update is called the Delta Weight.
#
# ---
#
# ## Delta Weight Equation
#
# The local update is computed as:
#
# $\Delta w_k^{(t)}
# =
# w_k^{(t)}
# -
# w^{(t)}$
#
# where:
#
# - $w^{(t)}$ is the received global model
# - $w_k^{(t)}$ is the locally trained client model
# - $\Delta w_k^{(t)}$ represents the local weight update
#
# This approach reduces redundant communication and focuses only on the learned changes.

# %%
def train_client(model, dataset):

    loader = DataLoader(
        dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
        drop_last=True
    )

    criterion = nn.CrossEntropyLoss()

    optimizer = optim.Adam(
        model.parameters(),
        lr=LEARNING_RATE
    )

    scheduler = torch.optim.lr_scheduler.StepLR(
        optimizer,
        step_size=1,
        gamma=0.9
    )

    # Save initial global weights
    initial_weights = {
        key: value.clone()
        for key, value in model.state_dict().items()
    }

    model.train()

    total_loss = 0

    for epoch in range(LOCAL_EPOCHS):

        epoch_loss = 0

        # FIXED PART
        for batch in loader:

            images = batch[0].to(DEVICE)
            labels = batch[1].to(DEVICE)

            optimizer.zero_grad()

            outputs = model(images)

            loss = criterion(outputs, labels)

            loss.backward()

            optimizer.step()

            epoch_loss += loss.item()

        scheduler.step()

        avg_epoch_loss = (
            epoch_loss / len(loader)
        )

        total_loss += avg_epoch_loss

    avg_client_loss = (
        total_loss / LOCAL_EPOCHS
    )

    # Compute delta weights
    delta_weights = {}

    for key in model.state_dict():

        delta_weights[key] = (
            model.state_dict()[key]
            - initial_weights[key]
        )

    return delta_weights, avg_client_loss

# %% [markdown]
# ## Aggregating Delta Updates
#
# The server aggregates the received delta updates from multiple clients.
#
# Instead of averaging full model weights, the server averages only the parameter changes.
#
# ---
#
# ## Delta Aggregation Equation
#
# The global update becomes:
#
# $w^{(t+1)}
# =
# w^{(t)}
# +
# \sum_{k=1}^{K}
# \frac{n_k}{n}
# \Delta w_k^{(t)}$
#
# where:
#
# - $\Delta w_k^{(t)}$ is the update from client $k$
# - $n_k$ is the number of samples in client $k$
# - $n$ is the total number of samples
#
# This updates the global model using the aggregated learning signal from all selected clients.

# %%
def federated_average(client_deltas):

    global_dict = global_model.state_dict()

    for key in global_dict.keys():

        avg_delta = torch.stack([
            client_deltas[i][key].float()
            for i in range(len(client_deltas))
        ], dim=0).mean(dim=0)

        # Add averaged delta
        global_dict[key] = (
            global_dict[key] + avg_delta
        )

    global_model.load_state_dict(global_dict)

    return global_model

# %% [markdown]
# ## Evaluating the Global Model
#
# This section evaluates the updated global model on the test dataset.
#
# The model performance is measured using classification accuracy.
#
#
# ## Accuracy Formula
#
# $\text{Accuracy}
# =
# \frac{\text{Correct Predictions}}
# {\text{Total Samples}}
# \times 100$
#
# Higher accuracy indicates better generalization performance.

# %%
test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False
)

def evaluate_model(model):

    model.eval()

    correct = 0
    total = 0

    with torch.no_grad():

        for images, labels in test_loader:

            images = images.to(DEVICE)
            labels = labels.to(DEVICE)

            outputs = model(images)

            _, predicted = torch.max(
                outputs,
                1
            )

            total += labels.size(0)

            correct += (
                predicted == labels
            ).sum().item()

    accuracy = 100 * correct / total

    return accuracy

# %% [markdown]
# # Federated Learning Training Process
#
# This is the main communication loop of the Federated Learning system.
#
# Each round consists of:
#
# 1. Selecting clients
# 2. Local training
# 3. Delta computation
# 4. Server aggregation
# 5. Global evaluation
#
# ---
#
# ## Global Update
#
# The server updates the model using:
#
# $w^{(t+1)}
# =
# w^{(t)}
# +
# \sum_{k=1}^{K}
# \frac{n_k}{n}
# \Delta w_k^{(t)}$
#
# The updated global model is then broadcast back to clients for the next communication round.

# %%
round_accuracies = []
round_losses = []

best_accuracy = 0

best_model_weights = None

for round_num in range(ROUNDS):

    start_time = time.time()

    print("=" * 70)
    print(f"ROUND {round_num+1}/{ROUNDS}")
    print("=" * 70)

    selected_clients = np.random.choice(
        NUM_CLIENTS,
        CLIENTS_PER_ROUND,
        replace=False
    )

    print("Selected Clients:", selected_clients)

    client_deltas = []
    client_losses = []

    for client_id in selected_clients:

        print(f"\nTraining Client {client_id}...")

        local_model = resnet18(
            num_classes=100
        ).to(DEVICE)

        local_model.load_state_dict(
            global_model.state_dict()
        )

        client_dataset = Subset(
    train_dataset,
    client_indices[client_id]
)

        deltas, loss = train_client(
            local_model,
            client_dataset
        )
        client_deltas.append(deltas)
        client_losses.append(loss)

        print(
            f"Client {client_id} "
            f"Loss: {loss:.4f}"
        )

        del local_model

        torch.cuda.empty_cache()

        gc.collect()

    federated_average(client_deltas)

    avg_loss = (
        sum(client_losses)
        / len(client_losses)
    )

    accuracy = evaluate_model(global_model)

    round_accuracies.append(accuracy)

    round_losses.append(avg_loss)

    if round_num == 0:
        accuracy_change = accuracy
    else:
        accuracy_change = (
            accuracy
            - round_accuracies[-2]
        )

    if accuracy > best_accuracy:

        best_accuracy = accuracy

        best_model_weights = copy.deepcopy(
            global_model.state_dict()
        )

    round_time = (
        time.time() - start_time
    )

    print("\n" + "=" * 70)
    print("ROUND SUMMARY")
    print("=" * 70)

    print(
        f"Average Client Loss : "
        f"{avg_loss:.4f}"
    )

    print(
        f"Global Accuracy     : "
        f"{accuracy:.2f}%"
    )

    print(
        f"Accuracy Change     : "
        f"{accuracy_change:+.2f}%"
    )

    print(
        f"Best Accuracy       : "
        f"{best_accuracy:.2f}%"
    )

    print(
        f"Round Duration      : "
        f"{round_time:.2f} sec"
    )

    print("=" * 70)
    print()
# Out:
# ======================================================================
# ROUND 1/20
# ======================================================================
# Selected Clients: [ 5 15 13 17  3 18  0  9 19 12]
#
# Training Client 5...
# Client 5 Loss: 3.5619
#
# Training Client 15...
# Client 15 Loss: 3.9545
#
# Training Client 13...
# Client 13 Loss: 3.8974
#
# Training Client 17...
# Client 17 Loss: 3.6671
#
# Training Client 3...
# Client 3 Loss: 3.7322
#
# Training Client 18...
# Client 18 Loss: 3.7261
#
# Training Client 0...
# Client 0 Loss: 3.9525
#
# Training Client 9...
# Client 9 Loss: 3.8604
#
# Training Client 19...
# Client 19 Loss: 3.7064
#
# Training Client 12...
# Client 12 Loss: 3.8352
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 3.7894
# Global Accuracy     : 3.17%
# Accuracy Change     : +3.17%
# Best Accuracy       : 3.17%
# Round Duration      : 40.47 sec
# ======================================================================
#
# ======================================================================
# ROUND 2/20
# ======================================================================
# Selected Clients: [ 8  2  0  4 14 11 18 10 17 12]
#
# Training Client 8...
# Client 8 Loss: 3.7430
#
# Training Client 2...
# Client 2 Loss: 3.5470
#
# Training Client 0...
# Client 0 Loss: 3.7950
#
# Training Client 4...
# Client 4 Loss: 3.7034
#
# Training Client 14...
# Client 14 Loss: 3.7277
#
# Training Client 11...
# Client 11 Loss: 3.6618
#
# Training Client 18...
# Client 18 Loss: 3.5908
#
# Training Client 10...
# Client 10 Loss: 3.7282
#
# Training Client 17...
# Client 17 Loss: 3.5332
#
# Training Client 12...
# Client 12 Loss: 3.7128
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 3.6743
# Global Accuracy     : 4.84%
# Accuracy Change     : +1.67%
# Best Accuracy       : 4.84%
# Round Duration      : 40.08 sec
# ======================================================================
#
# ======================================================================
# ROUND 3/20
# ======================================================================
# Selected Clients: [14 16 12 19 17  5 18 13 11  8]
#
# Training Client 14...
# Client 14 Loss: 3.5964
#
# Training Client 16...
# Client 16 Loss: 3.6400
#
# Training Client 12...
# Client 12 Loss: 3.5899
#
# Training Client 19...
# Client 19 Loss: 3.5643
#
# Training Client 17...
# Client 17 Loss: 3.5153
#
# Training Client 5...
# Client 5 Loss: 3.3628
#
# Training Client 18...
# Client 18 Loss: 3.4526
#
# Training Client 13...
# Client 13 Loss: 3.7044
#
# Training Client 11...
# Client 11 Loss: 3.5656
#
# Training Client 8...
# Client 8 Loss: 3.6142
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 3.5605
# Global Accuracy     : 6.76%
# Accuracy Change     : +1.92%
# Best Accuracy       : 6.76%
# Round Duration      : 41.28 sec
# ======================================================================
#
# ======================================================================
# ROUND 4/20
# ======================================================================
# Selected Clients: [18 13  5 10 15 12 17  0  9 14]
#
# Training Client 18...
# Client 18 Loss: 3.4181
#
# Training Client 13...
# Client 13 Loss: 3.6328
#
# Training Client 5...
# Client 5 Loss: 3.2847
#
# Training Client 10...
# Client 10 Loss: 3.5818
#
# Training Client 15...
# Client 15 Loss: 3.6225
#
# Training Client 12...
# Client 12 Loss: 3.5566
#
# Training Client 17...
# Client 17 Loss: 3.3940
#
# Training Client 0...
# Client 0 Loss: 3.6604
#
# Training Client 9...
# Client 9 Loss: 3.6712
#
# Training Client 14...
# Client 14 Loss: 3.5105
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 3.5333
# Global Accuracy     : 8.49%
# Accuracy Change     : +1.73%
# Best Accuracy       : 8.49%
# Round Duration      : 39.71 sec
# ======================================================================
#
# ======================================================================
# ROUND 5/20
# ======================================================================
# Selected Clients: [11 13 16 17  8  3  0  9  7  4]
#
# Training Client 11...
# Client 11 Loss: 3.4802
#
# Training Client 13...
# Client 13 Loss: 3.5463
#
# Training Client 16...
# Client 16 Loss: 3.4995
#
# Training Client 17...
# Client 17 Loss: 3.3425
#
# Training Client 8...
# Client 8 Loss: 3.5050
#
# Training Client 3...
# Client 3 Loss: 3.4165
#
# Training Client 0...
# Client 0 Loss: 3.6209
#
# Training Client 9...
# Client 9 Loss: 3.5723
#
# Training Client 7...
# Client 7 Loss: 3.4580
#
# Training Client 4...
# Client 4 Loss: 3.4791
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 3.4920
# Global Accuracy     : 9.42%
# Accuracy Change     : +0.93%
# Best Accuracy       : 9.42%
# Round Duration      : 40.07 sec
# ======================================================================
#
# ======================================================================
# ROUND 6/20
# ======================================================================
# Selected Clients: [12  5  2  7  6 11  4 10 16  8]
#
# Training Client 12...
# Client 12 Loss: 3.4314
#
# Training Client 5...
# Client 5 Loss: 3.1734
#
# Training Client 2...
# Client 2 Loss: 3.2931
#
# Training Client 7...
# Client 7 Loss: 3.3737
#
# Training Client 6...
# Client 6 Loss: 3.4980
#
# Training Client 11...
# Client 11 Loss: 3.3919
#
# Training Client 4...
# Client 4 Loss: 3.4343
#
# Training Client 10...
# Client 10 Loss: 3.5036
#
# Training Client 16...
# Client 16 Loss: 3.4479
#
# Training Client 8...
# Client 8 Loss: 3.4395
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 3.3987
# Global Accuracy     : 12.22%
# Accuracy Change     : +2.80%
# Best Accuracy       : 12.22%
# Round Duration      : 41.65 sec
# ======================================================================
#
# ======================================================================
# ROUND 7/20
# ======================================================================
# Selected Clients: [19 14  7  4 13  1 12  6 10  0]
#
# Training Client 19...
# Client 19 Loss: 3.3113
#
# Training Client 14...
# Client 14 Loss: 3.3971
#
# Training Client 7...
# Client 7 Loss: 3.2847
#
# Training Client 4...
# Client 4 Loss: 3.3319
#
# Training Client 13...
# Client 13 Loss: 3.4318
#
# Training Client 1...
# Client 1 Loss: 3.3445
#
# Training Client 12...
# Client 12 Loss: 3.4066
#
# Training Client 6...
# Client 6 Loss: 3.4105
#
# Training Client 10...
# Client 10 Loss: 3.4118
#
# Training Client 0...
# Client 0 Loss: 3.4456
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 3.3776
# Global Accuracy     : 13.33%
# Accuracy Change     : +1.11%
# Best Accuracy       : 13.33%
# Round Duration      : 42.03 sec
# ======================================================================
#
# ======================================================================
# ROUND 8/20
# ======================================================================
# Selected Clients: [15 14  7 18  0  2  8 19 10  6]
#
# Training Client 15...
# Client 15 Loss: 3.3770
#
# Training Client 14...
# Client 14 Loss: 3.3273
#
# Training Client 7...
# Client 7 Loss: 3.1930
#
# Training Client 18...
# Client 18 Loss: 3.2557
#
# Training Client 0...
# Client 0 Loss: 3.3073
#
# Training Client 2...
# Client 2 Loss: 3.1429
#
# Training Client 8...
# Client 8 Loss: 3.3360
#
# Training Client 19...
# Client 19 Loss: 3.2435
#
# Training Client 10...
# Client 10 Loss: 3.3813
#
# Training Client 6...
# Client 6 Loss: 3.3607
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 3.2925
# Global Accuracy     : 14.87%
# Accuracy Change     : +1.54%
# Best Accuracy       : 14.87%
# Round Duration      : 40.51 sec
# ======================================================================
#
# ======================================================================
# ROUND 9/20
# ======================================================================
# Selected Clients: [ 0 16 18 19 12 15 10 11  5 17]
#
# Training Client 0...
# Client 0 Loss: 3.3021
#
# Training Client 16...
# Client 16 Loss: 3.2583
#
# Training Client 18...
# Client 18 Loss: 3.1532
#
# Training Client 19...
# Client 19 Loss: 3.1841
#
# Training Client 12...
# Client 12 Loss: 3.2764
#
# Training Client 15...
# Client 15 Loss: 3.3043
#
# Training Client 10...
# Client 10 Loss: 3.2926
#
# Training Client 11...
# Client 11 Loss: 3.2655
#
# Training Client 5...
# Client 5 Loss: 2.9908
#
# Training Client 17...
# Client 17 Loss: 3.1672
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 3.2194
# Global Accuracy     : 16.68%
# Accuracy Change     : +1.81%
# Best Accuracy       : 16.68%
# Round Duration      : 39.96 sec
# ======================================================================
#
# ======================================================================
# ROUND 10/20
# ======================================================================
# Selected Clients: [ 5 14  7  0 15  3 18  6 11 17]
#
# Training Client 5...
# Client 5 Loss: 2.9733
#
# Training Client 14...
# Client 14 Loss: 3.2078
#
# Training Client 7...
# Client 7 Loss: 3.1074
#
# Training Client 0...
# Client 0 Loss: 3.2511
#
# Training Client 15...
# Client 15 Loss: 3.2573
#
# Training Client 3...
# Client 3 Loss: 3.1148
#
# Training Client 18...
# Client 18 Loss: 3.0947
#
# Training Client 6...
# Client 6 Loss: 3.2990
#
# Training Client 11...
# Client 11 Loss: 3.1636
#
# Training Client 17...
# Client 17 Loss: 3.1115
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 3.1580
# Global Accuracy     : 18.07%
# Accuracy Change     : +1.39%
# Best Accuracy       : 18.07%
# Round Duration      : 40.56 sec
# ======================================================================
#
# ======================================================================
# ROUND 11/20
# ======================================================================
# Selected Clients: [ 3 10  9 19  8 14 12  7 13  0]
#
# Training Client 3...
# Client 3 Loss: 3.0796
#
# Training Client 10...
# Client 10 Loss: 3.2261
#
# Training Client 9...
# Client 9 Loss: 3.2985
#
# Training Client 19...
# Client 19 Loss: 3.1320
#
# Training Client 8...
# Client 8 Loss: 3.2036
#
# Training Client 14...
# Client 14 Loss: 3.1578
#
# Training Client 12...
# Client 12 Loss: 3.2069
#
# Training Client 7...
# Client 7 Loss: 3.0248
#
# Training Client 13...
# Client 13 Loss: 3.2587
#
# Training Client 0...
# Client 0 Loss: 3.1763
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 3.1764
# Global Accuracy     : 19.03%
# Accuracy Change     : +0.96%
# Best Accuracy       : 19.03%
# Round Duration      : 40.92 sec
# ======================================================================
#
# ======================================================================
# ROUND 12/20
# ======================================================================
# Selected Clients: [18 13  0 15 14 19  6 10  1 12]
#
# Training Client 18...
# Client 18 Loss: 3.0428
#
# Training Client 13...
# Client 13 Loss: 3.1945
#
# Training Client 0...
# Client 0 Loss: 3.1350
#
# Training Client 15...
# Client 15 Loss: 3.1880
#
# Training Client 14...
# Client 14 Loss: 3.0731
#
# Training Client 19...
# Client 19 Loss: 3.0475
#
# Training Client 6...
# Client 6 Loss: 3.2337
#
# Training Client 10...
# Client 10 Loss: 3.1481
#
# Training Client 1...
# Client 1 Loss: 3.1026
#
# Training Client 12...
# Client 12 Loss: 3.1213
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 3.1287
# Global Accuracy     : 19.68%
# Accuracy Change     : +0.65%
# Best Accuracy       : 19.68%
# Round Duration      : 41.15 sec
# ======================================================================
#
# ======================================================================
# ROUND 13/20
# ======================================================================
# Selected Clients: [ 1  5  6 10 11  0 12 17 13  9]
#
# Training Client 1...
# Client 1 Loss: 3.0473
#
# Training Client 5...
# Client 5 Loss: 2.8006
#
# Training Client 6...
# Client 6 Loss: 3.1174
#
# Training Client 10...
# Client 10 Loss: 3.1045
#
# Training Client 11...
# Client 11 Loss: 3.0537
#
# Training Client 0...
# Client 0 Loss: 3.0813
#
# Training Client 12...
# Client 12 Loss: 3.0504
#
# Training Client 17...
# Client 17 Loss: 2.9743
#
# Training Client 13...
# Client 13 Loss: 3.1703
#
# Training Client 9...
# Client 9 Loss: 3.2618
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 3.0662
# Global Accuracy     : 20.71%
# Accuracy Change     : +1.03%
# Best Accuracy       : 20.71%
# Round Duration      : 42.21 sec
# ======================================================================
#
# ======================================================================
# ROUND 14/20
# ======================================================================
# Selected Clients: [18  7  0  2  5 19  8 16 15 10]
#
# Training Client 18...
# Client 18 Loss: 3.0258
#
# Training Client 7...
# Client 7 Loss: 2.9809
#
# Training Client 0...
# Client 0 Loss: 3.0445
#
# Training Client 2...
# Client 2 Loss: 2.9418
#
# Training Client 5...
# Client 5 Loss: 2.7842
#
# Training Client 19...
# Client 19 Loss: 2.9909
#
# Training Client 8...
# Client 8 Loss: 3.0453
#
# Training Client 16...
# Client 16 Loss: 3.0862
#
# Training Client 15...
# Client 15 Loss: 3.1505
#
# Training Client 10...
# Client 10 Loss: 3.0812
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 3.0131
# Global Accuracy     : 21.51%
# Accuracy Change     : +0.80%
# Best Accuracy       : 21.51%
# Round Duration      : 40.00 sec
# ======================================================================
#
# ======================================================================
# ROUND 15/20
# ======================================================================
# Selected Clients: [10 15 11  1 13  4  5 18  3  0]
#
# Training Client 10...
# Client 10 Loss: 3.0207
#
# Training Client 15...
# Client 15 Loss: 3.0509
#
# Training Client 11...
# Client 11 Loss: 2.9881
#
# Training Client 1...
# Client 1 Loss: 2.9631
#
# Training Client 13...
# Client 13 Loss: 3.0828
#
# Training Client 4...
# Client 4 Loss: 3.0086
#
# Training Client 5...
# Client 5 Loss: 2.7394
#
# Training Client 18...
# Client 18 Loss: 2.9242
#
# Training Client 3...
# Client 3 Loss: 2.9085
#
# Training Client 0...
# Client 0 Loss: 3.0143
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 2.9701
# Global Accuracy     : 21.77%
# Accuracy Change     : +0.26%
# Best Accuracy       : 21.77%
# Round Duration      : 40.21 sec
# ======================================================================
#
# ======================================================================
# ROUND 16/20
# ======================================================================
# Selected Clients: [ 9  5 15 17 11 18 12  2 19  4]
#
# Training Client 9...
# Client 9 Loss: 3.1367
#
# Training Client 5...
# Client 5 Loss: 2.6853
#
# Training Client 15...
# Client 15 Loss: 2.9834
#
# Training Client 17...
# Client 17 Loss: 2.9205
#
# Training Client 11...
# Client 11 Loss: 2.9856
#
# Training Client 18...
# Client 18 Loss: 2.8862
#
# Training Client 12...
# Client 12 Loss: 2.9708
#
# Training Client 2...
# Client 2 Loss: 2.8730
#
# Training Client 19...
# Client 19 Loss: 2.9247
#
# Training Client 4...
# Client 4 Loss: 2.9751
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 2.9341
# Global Accuracy     : 22.91%
# Accuracy Change     : +1.14%
# Best Accuracy       : 22.91%
# Round Duration      : 39.95 sec
# ======================================================================
#
# ======================================================================
# ROUND 17/20
# ======================================================================
# Selected Clients: [19 11  7 12 17  2  5  3 13  4]
#
# Training Client 19...
# Client 19 Loss: 2.8705
#
# Training Client 11...
# Client 11 Loss: 2.8776
#
# Training Client 7...
# Client 7 Loss: 2.8802
#
# Training Client 12...
# Client 12 Loss: 2.9390
#
# Training Client 17...
# Client 17 Loss: 2.8321
#
# Training Client 2...
# Client 2 Loss: 2.7959
#
# Training Client 5...
# Client 5 Loss: 2.6531
#
# Training Client 3...
# Client 3 Loss: 2.8650
#
# Training Client 13...
# Client 13 Loss: 2.9990
#
# Training Client 4...
# Client 4 Loss: 2.9061
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 2.8618
# Global Accuracy     : 23.28%
# Accuracy Change     : +0.37%
# Best Accuracy       : 23.28%
# Round Duration      : 40.96 sec
# ======================================================================
#
# ======================================================================
# ROUND 18/20
# ======================================================================
# Selected Clients: [16 10  0 12  5  1 14 19  4 11]
#
# Training Client 16...
# Client 16 Loss: 2.9875
#
# Training Client 10...
# Client 10 Loss: 2.9591
#
# Training Client 0...
# Client 0 Loss: 2.9514
#
# Training Client 12...
# Client 12 Loss: 2.8593
#
# Training Client 5...
# Client 5 Loss: 2.5807
#
# Training Client 1...
# Client 1 Loss: 2.8669
#
# Training Client 14...
# Client 14 Loss: 2.9516
#
# Training Client 19...
# Client 19 Loss: 2.8101
#
# Training Client 4...
# Client 4 Loss: 2.8646
#
# Training Client 11...
# Client 11 Loss: 2.8701
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 2.8701
# Global Accuracy     : 25.04%
# Accuracy Change     : +1.76%
# Best Accuracy       : 25.04%
# Round Duration      : 42.36 sec
# ======================================================================
#
# ======================================================================
# ROUND 19/20
# ======================================================================
# Selected Clients: [ 6  1 13 14  0 19 12 17 18  8]
#
# Training Client 6...
# Client 6 Loss: 2.9750
#
# Training Client 1...
# Client 1 Loss: 2.7929
#
# Training Client 13...
# Client 13 Loss: 2.9308
#
# Training Client 14...
# Client 14 Loss: 2.9131
#
# Training Client 0...
# Client 0 Loss: 2.8843
#
# Training Client 19...
# Client 19 Loss: 2.7684
#
# Training Client 12...
# Client 12 Loss: 2.8663
#
# Training Client 17...
# Client 17 Loss: 2.8247
#
# Training Client 18...
# Client 18 Loss: 2.8561
#
# Training Client 8...
# Client 8 Loss: 2.9251
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 2.8737
# Global Accuracy     : 26.34%
# Accuracy Change     : +1.30%
# Best Accuracy       : 26.34%
# Round Duration      : 41.02 sec
# ======================================================================
#
# ======================================================================
# ROUND 20/20
# ======================================================================
# Selected Clients: [16 12  7  5  1  2  4  3 10  9]
#
# Training Client 16...
# Client 16 Loss: 2.8896
#
# Training Client 12...
# Client 12 Loss: 2.8196
#
# Training Client 7...
# Client 7 Loss: 2.7303
#
# Training Client 5...
# Client 5 Loss: 2.5725
#
# Training Client 1...
# Client 1 Loss: 2.7319
#
# Training Client 2...
# Client 2 Loss: 2.7218
#
# Training Client 4...
# Client 4 Loss: 2.8080
#
# Training Client 3...
# Client 3 Loss: 2.7579
#
# Training Client 10...
# Client 10 Loss: 2.9235
#
# Training Client 9...
# Client 9 Loss: 2.9978
#
# ======================================================================
# ROUND SUMMARY
# ======================================================================
# Average Client Loss : 2.7953
# Global Accuracy     : 25.71%
# Accuracy Change     : -0.63%
# Best Accuracy       : 26.34%
# Round Duration      : 41.36 sec
# ======================================================================

# %%
global_model.load_state_dict(
    best_model_weights
)

print("Best Model Restored")

print(
    f"Best Accuracy: "
    f"{best_accuracy:.2f}%"
)
# Out:
# Best Model Restored
# Best Accuracy: 26.34%

# %% [markdown]
# ## Visualizing Global Accuracy
#
# This graph shows how the global model accuracy changes over communication rounds.
#
# An increasing accuracy trend generally indicates improved collaborative learning across clients.

# %%
plt.figure(figsize=(10,5))

plt.plot(round_accuracies)

plt.xlabel("Communication Rounds")

plt.ylabel("Accuracy (%)")

plt.title(
    "Federated Learning Accuracy"
)

plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# -------------------------------
# LOSS GRAPH
# -------------------------------

plt.figure(figsize=(8,5))

plt.plot(
    round_losses,
    marker='o'
)

plt.title("Federated Training Loss")

plt.xlabel("Rounds")

plt.ylabel("Loss")

plt.grid(True)

plt.show()

# %% [markdown]
# # Conclusion
#
# The federated learning model showed consistent improvement over 20 communication rounds. Global accuracy increased from 3.17% in Round 1 to a peak of 26.34% in Round 19, while the average client loss decreased from 3.79 to 2.80. This inverse relationship between accuracy and loss indicates that the model successfully learned useful feature representations across distributed clients. Although a slight drop in accuracy was observed in the final round (25.71%), the overall trend demonstrates stable convergence and effective aggregation of client updates. The results confirm that the FedAvg-based training process improved model performance over successive communication rounds.
